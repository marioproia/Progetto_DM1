# %%
import pandas as pd
import numpy as np
from matplotlib.pyplot import *
import matplotlib.pyplot as plt
import seaborn as sn
from sklearn.linear_model import LinearRegression
from scipy import stats

df_test = pd.read_csv("https://raw.githubusercontent.com/marioproia/Progetto_DM1/master/Test_HR_Employee_Attrition.csv?token=ANVE7JLUER3W3JV3UGB3EMC7V23RA")
df_train = pd.read_csv("https://raw.githubusercontent.com/marioproia/Progetto_DM1/master/Train_HR_Employee_Attrition.csv?token=ANVE7JJR2LXUAEARHY3CNH27V23SQ")

frame = [df_test, df_train]
df3 = pd.concat(frame)
df3.head()
# Out:
#     Age Attrition     BusinessTravel  DailyRate              Department  \
# 0  27.0       Yes  Travel_Frequently        763                   Sales
# 1  30.0       Yes      Travel_Rarely       1079                   Sales
# 2  56.0        No         Non-Travel        150  Research & Development
# 3  41.0       Yes                NaN        359         Human Resources
# 4  42.0        No                NaN        642  Research & Development
#
#    DistanceFromHome  Education    EducationField  EnvironmentSatisfaction  \
# 0                15          2           Medical                        1
# 1                16          4         Marketing                        1
# 2                 2          4  Technical Degree                        4
# 3                18          5   Human Resources                        4
# 4                 1          3     Life Sciences                        4
#
#   Gender  ...  RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# 0   Male  ...                         4           80.0                 2
# 1   Male  ...                         1            NaN                 3
# 2   Male  ...                         3           80.0                 1
# 3   Male  ...                         3           80.0                 0
# 4   Male  ...                         1            NaN                 1
#
#   TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0                 7                    1.0               2             2.0
# 1                10                    2.0               3             8.0
# 2                12                    2.0               2            13.0
# 3                 2                    4.0               3             3.0
# 4                12                    6.0               3             5.0
#
#    YearsInCurrentRole  YearsSinceLastPromotion YearsWithCurrManager
# 0                   2                        2                    2
# 1                   0                        0                    0
# 2                   3                        1                    4
# 3                   0                        0                    0
# 4                   3                        1                    0
#
# [5 rows x 33 columns]

# %% [markdown]
# **DATA UNDERSTANDING**

# %%
#HO AGGIUNTO PER PROVA "MonthlyIncome", "YearsWithCurrManager", "YearsSinceLastPromotion", "TrainingTimesLastYear", "NumCompaniesWorked", "MaritalStatus"
       
new_df = df3[['Age', 'Attrition', 'BusinessTravel',  'Department', 'DistanceFromHome', 'Education', 'EducationField','HourlyRate',
       'EnvironmentSatisfaction','Gender',  'JobLevel',  'JobSatisfaction', 'OverTime', 'PercentSalaryHike',
       'TotalWorkingYears', 'WorkLifeBalance',  'YearsAtCompany', 'YearsInCurrentRole', "MonthlyIncome", "YearsWithCurrManager", 
        "YearsSinceLastPromotion", "TrainingTimesLastYear", "NumCompaniesWorked", "MaritalStatus", "PerformanceRating"]]

new_df.head()
# Out:
#     Age Attrition     BusinessTravel              Department  \
# 0  27.0       Yes  Travel_Frequently                   Sales
# 1  30.0       Yes      Travel_Rarely                   Sales
# 2  56.0        No         Non-Travel  Research & Development
# 3  41.0       Yes                NaN         Human Resources
# 4  42.0        No                NaN  Research & Development
#
#    DistanceFromHome  Education    EducationField  HourlyRate  \
# 0                15          2           Medical          59
# 1                16          4         Marketing          70
# 2                 2          4  Technical Degree          60
# 3                18          5   Human Resources          89
# 4                 1          3     Life Sciences          76
#
#    EnvironmentSatisfaction Gender  ...  WorkLifeBalance  YearsAtCompany  \
# 0                        1   Male  ...                2             2.0
# 1                        1   Male  ...                3             8.0
# 2                        4   Male  ...                2            13.0
# 3                        4   Male  ...                3             3.0
# 4                        4   Male  ...                3             5.0
#
#   YearsInCurrentRole  MonthlyIncome  YearsWithCurrManager  \
# 0                  2         4298.0                     2
# 1                  0         5304.0                     0
# 2                  3         6306.0                     4
# 3                  0         6430.0                     0
# 4                  3         2766.0                     0
#
#    YearsSinceLastPromotion  TrainingTimesLastYear  NumCompaniesWorked  \
# 0                        2                    1.0                   6
# 1                        0                    2.0                   2
# 2                        1                    2.0                   2
# 3                        0                    4.0                   0
# 4                        1                    6.0                   3
#
#    MaritalStatus  PerformanceRating
# 0       Divorced                3.0
# 1        Married                4.0
# 2       Divorced                4.0
# 3        Married                3.0
# 4        Married                4.0
#
# [5 rows x 25 columns]

# %%
categoriche = new_df[["Attrition","BusinessTravel","Department","Gender","OverTime","EducationField","MaritalStatus"]]
categoriche.describe()
# Out:
#        Attrition BusinessTravel              Department Gender OverTime  \
# count       1470           1339                    1470   1395     1470
# unique         2              3                       3      2        2
# top           No  Travel_Rarely  Research & Development   Male       No
# freq        1233            947                     961    841     1054
#
#        EducationField MaritalStatus
# count            1470          1470
# unique              6             3
# top     Life Sciences       Married
# freq              606           673

# %%
new_df = new_df.replace(to_replace="Yes", value=1, inplace=False, limit=None, regex=False, method='pad')
new_df = new_df.replace(to_replace="No", value=0, inplace=False, limit=None, regex=False, method='pad')

new_df.head()
# Out:
#     Age  Attrition     BusinessTravel              Department  \
# 0  27.0          1  Travel_Frequently                   Sales
# 1  30.0          1      Travel_Rarely                   Sales
# 2  56.0          0         Non-Travel  Research & Development
# 3  41.0          1                NaN         Human Resources
# 4  42.0          0                NaN  Research & Development
#
#    DistanceFromHome  Education    EducationField  HourlyRate  \
# 0                15          2           Medical          59
# 1                16          4         Marketing          70
# 2                 2          4  Technical Degree          60
# 3                18          5   Human Resources          89
# 4                 1          3     Life Sciences          76
#
#    EnvironmentSatisfaction Gender  ...  WorkLifeBalance  YearsAtCompany  \
# 0                        1   Male  ...                2             2.0
# 1                        1   Male  ...                3             8.0
# 2                        4   Male  ...                2            13.0
# 3                        4   Male  ...                3             3.0
# 4                        4   Male  ...                3             5.0
#
#    YearsInCurrentRole  MonthlyIncome  YearsWithCurrManager  \
# 0                   2         4298.0                     2
# 1                   0         5304.0                     0
# 2                   3         6306.0                     4
# 3                   0         6430.0                     0
# 4                   3         2766.0                     0
#
#    YearsSinceLastPromotion  TrainingTimesLastYear  NumCompaniesWorked  \
# 0                        2                    1.0                   6
# 1                        0                    2.0                   2
# 2                        1                    2.0                   2
# 3                        0                    4.0                   0
# 4                        1                    6.0                   3
#
#    MaritalStatus  PerformanceRating
# 0       Divorced                3.0
# 1        Married                4.0
# 2       Divorced                4.0
# 3        Married                3.0
# 4        Married                4.0
#
# [5 rows x 25 columns]

# %%
#Vedere se spostare quuesto blocco nella sezione Variable Transformation
new_df = new_df.replace(to_replace="Divorced", value=0, inplace=False, limit=None, regex=False, method='pad')
new_df = new_df.replace(to_replace="Married", value=2, inplace=False, limit=None, regex=False, method='pad')
new_df = new_df.replace(to_replace="Single", value=1, inplace=False, limit=None, regex=False, method='pad')

new_df.head()
# Out:
#     Age  Attrition     BusinessTravel              Department  \
# 0  27.0          1  Travel_Frequently                   Sales
# 1  30.0          1      Travel_Rarely                   Sales
# 2  56.0          0         Non-Travel  Research & Development
# 3  41.0          1                NaN         Human Resources
# 4  42.0          0                NaN  Research & Development
#
#    DistanceFromHome  Education    EducationField  HourlyRate  \
# 0                15          2           Medical          59
# 1                16          4         Marketing          70
# 2                 2          4  Technical Degree          60
# 3                18          5   Human Resources          89
# 4                 1          3     Life Sciences          76
#
#    EnvironmentSatisfaction Gender  ...  WorkLifeBalance  YearsAtCompany  \
# 0                        1   Male  ...                2             2.0
# 1                        1   Male  ...                3             8.0
# 2                        4   Male  ...                2            13.0
# 3                        4   Male  ...                3             3.0
# 4                        4   Male  ...                3             5.0
#
#    YearsInCurrentRole  MonthlyIncome  YearsWithCurrManager  \
# 0                   2         4298.0                     2
# 1                   0         5304.0                     0
# 2                   3         6306.0                     4
# 3                   0         6430.0                     0
# 4                   3         2766.0                     0
#
#    YearsSinceLastPromotion  TrainingTimesLastYear  NumCompaniesWorked  \
# 0                        2                    1.0                   6
# 1                        0                    2.0                   2
# 2                        1                    2.0                   2
# 3                        0                    4.0                   0
# 4                        1                    6.0                   3
#
#    MaritalStatus  PerformanceRating
# 0              0                3.0
# 1              2                4.0
# 2              0                4.0
# 3              2                3.0
# 4              2                4.0
#
# [5 rows x 25 columns]

# %%
round((new_df["MaritalStatus"].value_counts()/len(new_df))*100, 2)
# Out:
# 2    45.78
# 1    31.97
# 0    22.24
# Name: MaritalStatus, dtype: float64

# %%
round((new_df["Department"].value_counts()/len(new_df))*100, 2)
# Out:
# Research & Development    65.37
# Sales                     30.34
# Human Resources            4.29
# Name: Department, dtype: float64

# %%
#Percentuale di valori mancanti per ogni colonna
round((new_df.isnull().sum()/len(new_df))*100, 2)
# Out:
# Age                        14.42
# Attrition                   0.00
# BusinessTravel              8.91
# Department                  0.00
# DistanceFromHome            0.00
# Education                   0.00
# EducationField              0.00
# HourlyRate                  0.00
# EnvironmentSatisfaction     0.00
# Gender                      5.10
# JobLevel                    0.00
# JobSatisfaction             0.00
# OverTime                    0.00
# PercentSalaryHike           0.00
# TotalWorkingYears           0.00
# WorkLifeBalance             0.00
# YearsAtCompany              5.03
# YearsInCurrentRole          0.00
# MonthlyIncome              19.05
# YearsWithCurrManager        0.00
# YearsSinceLastPromotion     0.00
# TrainingTimesLastYear      19.86
# NumCompaniesWorked          0.00
# MaritalStatus               0.00
# PerformanceRating          11.70
# dtype: float64

# %%
new_df["Attrition"].value_counts().plot(kind='bar', color=("C0", "C1")).set_title("Attrition")
plt.show()

# %%
new_df.shape
# Out:
# (1470, 25)

# %%
new_df.describe()
# Out:
#                Age    Attrition  DistanceFromHome    Education   HourlyRate  \
# count  1258.000000  1470.000000       1470.000000  1470.000000  1470.000000
# mean     37.115262     0.161224          9.192517     2.912925    65.891156
# std       9.068654     0.367863          8.106864     1.024165    20.329428
# min      18.000000     0.000000          1.000000     1.000000    30.000000
# 25%      30.000000     0.000000          2.000000     2.000000    48.000000
# 50%      36.000000     0.000000          7.000000     3.000000    66.000000
# 75%      43.000000     0.000000         14.000000     4.000000    83.750000
# max      60.000000     1.000000         29.000000     5.000000   100.000000
#
#        EnvironmentSatisfaction     JobLevel  JobSatisfaction     OverTime  \
# count              1470.000000  1470.000000      1470.000000  1470.000000
# mean                  2.721769     2.063946         2.728571     0.282993
# std                   1.093082     1.106940         1.102846     0.450606
# min                   1.000000     1.000000         1.000000     0.000000
# 25%                   2.000000     1.000000         2.000000     0.000000
# 50%                   3.000000     2.000000         3.000000     0.000000
# 75%                   4.000000     3.000000         4.000000     1.000000
# max                   4.000000     5.000000         4.000000     1.000000
#
#        PercentSalaryHike  ...  WorkLifeBalance  YearsAtCompany  \
# count        1470.000000  ...      1470.000000     1396.000000
# mean           15.209524  ...         2.761224        6.942693
# std             3.659938  ...         0.706476        6.033444
# min            11.000000  ...         1.000000        0.000000
# 25%            12.000000  ...         2.000000        3.000000
# 50%            14.000000  ...         3.000000        5.000000
# 75%            18.000000  ...         3.000000        9.000000
# max            25.000000  ...         4.000000       40.000000
#
#        YearsInCurrentRole  MonthlyIncome  YearsWithCurrManager  \
# count         1470.000000    1190.000000           1470.000000
# mean             4.229252    6548.915966              4.123129
# std              3.623137    4732.775331              3.568136
# min              0.000000    1009.000000              0.000000
# 25%              2.000000    2973.250000              2.000000
# 50%              3.000000    4907.500000              3.000000
# 75%              7.000000    8437.500000              7.000000
# max             18.000000   19999.000000             17.000000
#
#        YearsSinceLastPromotion  TrainingTimesLastYear  NumCompaniesWorked  \
# count              1470.000000            1178.000000         1470.000000
# mean                  2.187755               2.810696            2.693197
# std                   3.222430               1.302499            2.498009
# min                   0.000000               0.000000            0.000000
# 25%                   0.000000               2.000000            1.000000
# 50%                   1.000000               3.000000            2.000000
# 75%                   3.000000               3.000000            4.000000
# max                  15.000000               6.000000            9.000000
#
#        MaritalStatus  PerformanceRating
# count    1470.000000        1298.000000
# mean        1.235374           3.154083
# std         0.790757           0.361168
# min         0.000000           3.000000
# 25%         1.000000           3.000000
# 50%         1.000000           3.000000
# 75%         2.000000           3.000000
# max         2.000000           4.000000
#
# [8 rows x 21 columns]

# %%
# Set up a grid of plots
fig = plt.figure(figsize=(15, 15)) 
fig_dims = (4,4)
fig.subplots_adjust(hspace=0.6, wspace=0.6)

# Plot Age
plt.subplot2grid(fig_dims, (0,0))
plt.ylabel("Frequency", size=15)
plt.xlabel("Age", size=15)
new_df['Age'].plot(kind='hist', bins=12)
plt.axvline(x=new_df["Age"].mean(), linestyle='--', linewidth=2.5, color="red", label="Mean")
plt.axvline(x=new_df["Age"].mean() + 3*new_df["Age"].std(), linestyle='--', linewidth=2.5, color="black", label="Upper")
plt.axvline(x=new_df["Age"].mean() - 3*new_df["Age"].std(), linestyle='--', linewidth=2.5, color="black", label="Lower")

# Plot DistanceFromHome
plt.subplot2grid(fig_dims, (0,1))
plt.ylabel("Frequency", size=15)
plt.xlabel("DistanceFromHome", size=15)
new_df['DistanceFromHome'].plot(kind='hist', bins=12)
plt.axvline(x=new_df["DistanceFromHome"].mean(), linestyle='--', linewidth=2.5, color="red", label="Mean")
plt.axvline(x=new_df["DistanceFromHome"].mean() + 3*new_df["DistanceFromHome"].std(), linestyle='--', linewidth=2.5, color="black", label="Upper")
plt.axvline(x=new_df["DistanceFromHome"].mean() - 3*new_df["DistanceFromHome"].std(), linestyle='--', linewidth=2.5, color="black", label="Lower")

# Plot HourlyRate
plt.subplot2grid(fig_dims, (0,2))
plt.ylabel("Frequency", size=15)
plt.xlabel("HourlyRate", size=15)
new_df['HourlyRate'].plot(kind='hist', bins=12)
plt.axvline(x=new_df["HourlyRate"].mean(), linestyle='--', linewidth=2.5, color="red", label="Mean")
plt.axvline(x=new_df["HourlyRate"].mean() + 3*new_df["HourlyRate"].std(), linestyle='--', linewidth=2.5, color="black", label="Upper")
plt.axvline(x=new_df["HourlyRate"].mean() - 3*new_df["HourlyRate"].std(), linestyle='--', linewidth=2.5, color="black", label="Lower")

# Plot PercentSalaryHike
plt.subplot2grid(fig_dims, (0,3))
plt.ylabel("Frequency", size=15)
plt.xlabel("PercentSalaryHike", size=15)
new_df['PercentSalaryHike'].plot(kind='hist', bins=12)
plt.axvline(x=new_df["PercentSalaryHike"].mean(), linestyle='--', linewidth=2.5, color="red", label="Mean")
plt.axvline(x=new_df["PercentSalaryHike"].mean() + 3*new_df["PercentSalaryHike"].std(), linestyle='--', linewidth=2.5, color="black", label="Upper")
plt.axvline(x=new_df["PercentSalaryHike"].mean() - 3*new_df["PercentSalaryHike"].std(), linestyle='--', linewidth=2.5, color="black", label="Lower")

# Plot TotalWorkingYears
plt.subplot2grid(fig_dims, (1,0))
plt.ylabel("Frequency", size=15)
plt.xlabel("TotalWorkingYears", size=15)
new_df['TotalWorkingYears'].plot(kind='hist', bins=12)
plt.axvline(x=new_df["TotalWorkingYears"].mean(), linestyle='--', linewidth=2.5, color="red", label="Mean")
plt.axvline(x=new_df["TotalWorkingYears"].mean() + 3*new_df["TotalWorkingYears"].std(), linestyle='--', linewidth=2.5, color="black", label="Upper")
plt.axvline(x=new_df["TotalWorkingYears"].mean() - 3*new_df["TotalWorkingYears"].std(), linestyle='--', linewidth=2.5, color="black", label="Lower")

# Plot YearsAtCompany
plt.subplot2grid(fig_dims, (1,1))
plt.ylabel("Frequency", size=15)
plt.xlabel("YearsAtCompany", size=15)
new_df['YearsAtCompany'].plot(kind='hist', bins=12)
plt.axvline(x=new_df["YearsAtCompany"].mean(), linestyle='--', linewidth=2.5, color="red", label="Mean")
plt.axvline(x=new_df["YearsAtCompany"].mean() + 3*new_df["YearsAtCompany"].std(), linestyle='--', linewidth=2.5, color="black", label="Upper")
plt.axvline(x=new_df["YearsAtCompany"].mean() - 3*new_df["YearsAtCompany"].std(), linestyle='--', linewidth=2.5, color="black", label="Lower")

# Plot YearsInCurrentRole
plt.subplot2grid(fig_dims, (1,2))
plt.ylabel("Frequency", size=15)
plt.xlabel("YearsInCurrentRole", size=15)
new_df['YearsInCurrentRole'].plot(kind='hist', bins=12)
plt.axvline(x=new_df["YearsInCurrentRole"].mean(), linestyle='--', linewidth=2.5, color="red", label="Mean")
plt.axvline(x=new_df["YearsInCurrentRole"].mean() + 3*new_df["YearsInCurrentRole"].std(), linestyle='--', linewidth=2.5, color="black", label="Upper")
plt.axvline(x=new_df["YearsInCurrentRole"].mean() - 3*new_df["YearsInCurrentRole"].std(), linestyle='--', linewidth=2.5, color="black", label="Lower")

# Plot YearsWithCurrManager
plt.subplot2grid(fig_dims, (1,3))
plt.ylabel("Frequency", size=15)
plt.xlabel("YearsWithCurrManager", size=15)
new_df['YearsWithCurrManager'].plot(kind='hist', bins=12)
plt.axvline(x=new_df["YearsWithCurrManager"].mean(), linestyle='--', linewidth=2.5, color="red", label="Mean")
plt.axvline(x=new_df["YearsWithCurrManager"].mean() + 3*new_df["YearsWithCurrManager"].std(), linestyle='--', linewidth=2.5, color="black", label="Upper")
plt.axvline(x=new_df["YearsWithCurrManager"].mean() - 3*new_df["YearsWithCurrManager"].std(), linestyle='--', linewidth=2.5, color="black", label="Lower")

# Plot YearsSinceLastPromotion
plt.subplot2grid(fig_dims, (2,1))
plt.ylabel("Frequency", size=15)
plt.xlabel("YearsSinceLastPromotion", size=15)
new_df['YearsSinceLastPromotion'].plot(kind='hist', bins=12)
plt.axvline(x=new_df["YearsSinceLastPromotion"].mean(), linestyle='--', linewidth=2.5, color="red", label="Mean")
plt.axvline(x=new_df["YearsSinceLastPromotion"].mean() + 3*new_df["YearsSinceLastPromotion"].std(), linestyle='--', linewidth=2.5, color="black", label="Upper")
plt.axvline(x=new_df["YearsSinceLastPromotion"].mean() - 3*new_df["YearsSinceLastPromotion"].std(), linestyle='--', linewidth=2.5, color="black", label="Lower")

# Plot MonthlyIncome
plt.subplot2grid(fig_dims, (2,2))
plt.ylabel("Frequency", size=15)
plt.xlabel("MonthlyIncome", size=15)
new_df['MonthlyIncome'].plot(kind='hist', bins=12)
plt.axvline(x=new_df["MonthlyIncome"].mean(), linestyle='--', linewidth=2.5, color="red", label="Mean")
plt.axvline(x=new_df["MonthlyIncome"].mean() + 3*new_df["MonthlyIncome"].std(), linestyle='--', linewidth=2.5, color="black", label="Upper")
plt.axvline(x=new_df["MonthlyIncome"].mean() - 3*new_df["MonthlyIncome"].std(), linestyle='--', linewidth=2.5, color="black", label="Lower")

plt.show()

# %% [markdown]
# **DATA QUALITY**

# %%
corrMatrix = new_df.corr()
corrMatrix.head()
# Out:
#                        Age  Attrition  DistanceFromHome  Education  \
# Age               1.000000  -0.014636          0.015202   0.007189
# Attrition        -0.014636   1.000000          0.077924  -0.031373
# DistanceFromHome  0.015202   0.077924          1.000000   0.021042
# Education         0.007189  -0.031373          0.021042   1.000000
# HourlyRate        0.035321  -0.006846          0.031131   0.016775
#
#                   HourlyRate  EnvironmentSatisfaction  JobLevel  \
# Age                 0.035321                 0.022005  0.025911
# Attrition          -0.006846                -0.103369 -0.169105
# DistanceFromHome    0.031131                -0.016075  0.005303
# Education           0.016775                -0.027128  0.101589
# HourlyRate          1.000000                -0.049857 -0.027853
#
#                   JobSatisfaction  OverTime  PercentSalaryHike  ...  \
# Age                     -0.060127 -0.030357          -0.019252  ...
# Attrition               -0.103481  0.246118          -0.013478  ...
# DistanceFromHome        -0.003669  0.025514           0.040235  ...
# Education               -0.011296 -0.020322          -0.011111  ...
# HourlyRate              -0.071335 -0.007782          -0.009062  ...
#
#                   WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# Age                      0.018151        0.317141            0.028593
# Attrition               -0.063939        0.025215           -0.160545
# DistanceFromHome        -0.026556        0.023703            0.018845
# Education                0.009819        0.031169            0.060236
# HourlyRate              -0.004607        0.003561           -0.024106
#
#                   MonthlyIncome  YearsWithCurrManager  \
# Age                    0.516530              0.004606
# Attrition             -0.000596             -0.156199
# DistanceFromHome       0.000934              0.014406
# Education              0.005028              0.069065
# HourlyRate            -0.011316             -0.020123
#
#                   YearsSinceLastPromotion  TrainingTimesLastYear  \
# Age                              0.005130              -0.017919
# Attrition                       -0.033019              -0.030096
# DistanceFromHome                 0.010029               0.006346
# Education                        0.054254               0.000263
# HourlyRate                      -0.026716              -0.011816
#
#                   NumCompaniesWorked  MaritalStatus  PerformanceRating
# Age                        -0.011009      -0.017614          -0.006773
# Attrition                   0.043494      -0.011195           0.021303
# DistanceFromHome           -0.029251       0.021916          -0.029054
# Education                   0.126317       0.000107           0.036321
# HourlyRate                  0.022157       0.026198           0.005241
#
# [5 rows x 21 columns]

# %%
#Provare ad aggiungere delle colonne che abbiamo rimosso per vedere la correlazione con Attrition (corr molto basse)

mask = np.triu(np.ones_like(corrMatrix, dtype=bool))
fig, ax = plt.subplots(figsize=(15,15))

sn.heatmap(
    corrMatrix.round(2), 
    annot=True,
    annot_kws={"size":10},
    cmap=sn.diverging_palette(20, 220, n=200), 
    vmin=-1, 
    vmax=1, 
    center=0,
    linewidth=0.1,
    mask=mask,
    ax=ax)

bottom, top = ax.get_ylim()
ax.set_ylim(bottom+0.5, top-0.5)

plt.show()

fig.savefig("corrMat_con")

# %%
male_df = new_df[new_df["Gender"] == "Male"]
male_df["MonthlyIncome"].median()
# Out:
# 4865.5

# %%
female_df = new_df[new_df["Gender"] == "Female"]
female_df["MonthlyIncome"].median()
# Out:
# 5107.0

# %%
medie = new_df.groupby(new_df["Attrition"])
medie.mean()
# Out:
#                  Age  DistanceFromHome  Education  HourlyRate  \
# Attrition
# 0          37.173460          8.915653   2.927007   65.952149
# 1          36.812808         10.632911   2.839662   65.573840
#
#            EnvironmentSatisfaction  JobLevel  JobSatisfaction  OverTime  \
# Attrition
# 0                         2.771290  2.145985         2.778589  0.234388
# 1                         2.464135  1.637131         2.468354  0.535865
#
#            PercentSalaryHike  TotalWorkingYears  WorkLifeBalance  \
# Attrition
# 0                  15.231144          11.862936         2.781022
# 1                  15.097046           8.244726         2.658228
#
#            YearsAtCompany  YearsInCurrentRole  MonthlyIncome  \
# Attrition
# 0                6.876385            4.484185    6550.136727
# 1                7.291480            2.902954    6542.409574
#
#            YearsWithCurrManager  YearsSinceLastPromotion  \
# Attrition
# 0                      4.367397                 2.234388
# 1                      2.852321                 1.945148
#
#            TrainingTimesLastYear  NumCompaniesWorked  MaritalStatus  \
# Attrition
# 0                       2.827173            2.645580       1.239254
# 1                       2.717514            2.940928       1.215190
#
#            PerformanceRating
# Attrition
# 0                   3.150647
# 1                   3.171296
